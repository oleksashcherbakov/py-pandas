# %% [markdown]
# # Pandas

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `pandas` libraries.
#
#
# > Don't forget to import `numpy`, and `pandas` in short form.

# %%
import datetime

import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 2
#
# Create a `DataFrame` from the given dictionary `data`.

# %%
data = {
    "Name": ["John", "Emily", "Ryan"],
    "Age": [16, 28, 22],
    "City": ["New York", "Los Angeles", "Chicago"],
}
current_DF = pd.DataFrame(data)
print(current_DF)
# Out:
#     Name  Age         City
# 0   John   16     New York
# 1  Emily   28  Los Angeles
# 2   Ryan   22      Chicago

# %% [markdown]
# ## Task 3
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 3.1
# Display all data for `Age` column for the DataFrame you created in the previous task.

# %%
column_age = current_DF["Age"]
print(column_age)
# Out:
# 0    16
# 1    28
# 2    22
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 3.2
#
# Add `Salary` column to the `DataFrame` with the values `[50000, 60000, 45000]`.

# %%
current_DF["Salary"] = [50000, 60000, 45000]
print(current_DF)
# Out:
#     Name  Age         City  Salary
# 0   John   16     New York   50000
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ### Task 3.3
#
# Filter the `DataFrame` to show only the rows with the `Age` greater than 18.

# %%
filter_by_age_18 = current_DF[current_DF["Age"] > 18]
print(filter_by_age_18)
# Out:
#     Name  Age         City  Salary
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ## Task 4
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 4.1
#
# Add new calculated field `Birth year`;

# %%
current_year = datetime.datetime.now().year
current_DF["Birth year"] = current_year - current_DF["Age"]
print(current_DF)
# Out:
#     Name  Age         City  Salary  Birth year
# 0   John   16     New York   50000        2009
# 1  Emily   28  Los Angeles   60000        1997
# 2   Ryan   22      Chicago   45000        2003

# %% [markdown]
# ### Task 4.2
#
# Add new calculated field `Average age`.

# %%
average_age = current_DF["Age"].mean()
current_DF['Average age'] = average_age
print(current_DF)
# Out:
#     Name  Age         City  Salary  Birth year  Average age
# 0   John   16     New York   50000        2009         22.0
# 1  Emily   28  Los Angeles   60000        1997         22.0
# 2   Ryan   22      Chicago   45000        2003         22.0

# %% [markdown]
# ### Task 4.3
#
# Calculate absolute difference between `Age` and `Average age`.

# %%
current_DF["Absolute difference"] = (current_DF["Age"] - current_DF["Average age"]).abs()
print(current_DF)
# Out:
#     Name  Age         City  Salary  Birth year  Average age  \
# 0   John   16     New York   50000        2009         22.0
# 1  Emily   28  Los Angeles   60000        1997         22.0
# 2   Ryan   22      Chicago   45000        2003         22.0
#
#    Absolute difference
# 0                  6.0
# 1                  6.0
# 2                  0.0

# %% [markdown]
# ## Task 5
#
# Complete the following tasks described below.

# %% [markdown]
# ### Task 5.1
#
# You have two dictionaries `data1` and `data2`. Create two `DataFrame` objects from these dictionaries. Then, `concatenate`, and `merge` these two `DataFrame` objects into one `DataFrame` object, and see the difference.

# %%
# Data
data1 = {'Name': ['John', 'Emily', 'Ryan'],
         'Age': [25, 28, 22]}
data2 = {'Name': ['Emily', 'Ryan', 'Mike'],
         'City': ['Los Angeles', 'Chicago', 'Houston']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
print(df1, df2)
# Out:
#     Name  Age
# 0   John   25
# 1  Emily   28
# 2   Ryan   22     Name         City
# 0  Emily  Los Angeles
# 1   Ryan      Chicago
# 2   Mike      Houston

# %%
merged_df = pd.merge(df1, df2, on="id")
print(merged_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25436\1574494971.py in ?()
# ----> 1 merged_df = pd.merge(df1, df2, on='id')
#       2 print(merged_df)
#
# D:\Python\PythonProject\py-pandas\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# D:\Python\PythonProject\py-pandas\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# D:\Python\PythonProject\py-pandas\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1294                         # Then we're either Hashable or a wrong-length arraylike,
#    1295                         #  the latter of which will raise
#    1296                         rk = cast(Hashable, rk)
#    1297                         if rk is not None:
# -> 1298                             right_keys.append(right._get_label_or_level_values(rk))
#    1299                         else:
#    1300                             # work-around for merge_asof(right_index=True)
#    1301                             right_keys.append(right.index._values)
#
# D:\Python\PythonProject\py-pandas\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'id'

# %%
concatenated_df = pd.concat([df1, df2], ignore_index=True)
print(concatenated_df)
# Out:
#     Name   Age         City
# 0   John  25.0          NaN
# 1  Emily  28.0          NaN
# 2   Ryan  22.0          NaN
# 3  Emily   NaN  Los Angeles
# 4   Ryan   NaN      Chicago
# 5   Mike   NaN      Houston

# %% [markdown]
# ### Task 5.2
#
# You have two `Series` objects `s1` and `s2`. Make default mathematical operations on these two `Series` objects. Such as `+`, `-`, `*`, `/`, `**`, `//`, `%`. Also, filter `s1` and print only even numbers, and `s2` only with odd numbers.

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([6, 7, 8, 9, 10])

# %%
sum_s=s1+s2
print(sum_s)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
sub_s=s1-s2
print(sub_s)
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
mult_s=s1*s2
print(mult_s)
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
divide_s=s1/s2
print(divide_s)
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
mult_s=s1**s2
print(mult_s)
# Out:
# 0          1
# 1        128
# 2       6561
# 3     262144
# 4    9765625
# dtype: int64

# %%
div_s=s1//s2
print(div_s)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
new_div=s1%s2
print(new_div)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
res = s1[s1 % 2 == 0]
print(res)
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
res = s2[s2 % 2 != 0]
print(res)
# Out:
# 1    7
# 3    9
# dtype: int64

# %% [markdown]
# ### Task 5.3
#
# You have a `Serias` object `s`. Make the following operations on this `Series` object:
#
# * make all words in uppercase without loops;
# * get length of each word without loops.

# %%
s = pd.Series(["numpy", "pandas", "matplotlib"])

# %%
upper_s=s.str.upper()
print(upper_s)
# Out:
# 0         NUMPY
# 1        PANDAS
# 2    MATPLOTLIB
# dtype: object

# %%
len_s=s.str.len()
print(len_s)
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %% [markdown]
# ## Task 6 Optional
#
# You have a large dataset consisting of a series of numbers. Your task is to calculate the moving average of the series using a window of `5` elements. The moving average is the average of a set of consecutive values in the series, where the window `slides` through the series to compute the average at each position. The goal is to calculate the moving average efficiently and accurately. Also, compare time performance of Python and Pandas solutions.
#
# > Please, note: If you get `nan` while calculating the moving average, you should remove it from the result. Pandas solution should take 1-2 lines of code.

# %% [markdown]
# ### Python Solution
#
# In the Python solution, a large dataset is generated using random numbers. The moving average is computed by iterating over the dataset using a loop. At each position, a window of 5 elements is created, and the average is calculated by summing the values in the window and dividing by 5.

# %%
import random

def unknown_signature():
    # Generate a large dataset
    data = [random.randint(1, 100) for _ in range(10000000)]

    # Calculate the moving average with a window of 5
    moving_averages = []
    for i in range(4, len(data)):
        window = data[i - 4 : i + 1]
        average = sum(window) / 5
        moving_averages.append(average)
    return moving_averages[:10]

# %time unknown_signature()

# %% [markdown]
# ### Solution using Pandas and Numpy

# %%
# write your code here
